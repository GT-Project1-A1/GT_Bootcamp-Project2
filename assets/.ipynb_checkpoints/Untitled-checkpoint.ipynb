# %%
# Dependencies
from flask import Flask, render_template, redirect, Markup, jsonify
from flask_pymongo import PyMongo
from bson.json_util import dumps
import pymongo
from flask_cors import CORS
import pandas as pd
import json

# %%
app = Flask(__name__)

CORS(app, support_credentials = True)

# Use flask_pymongo to set up mongo connection
app.config["MONGO_URI"] = "mongodb://localhost:27017/election2020"
mongo = PyMongo(app)

# %%
# create route that rendrs index.html template
# @app.route("/")
def index():
    
    
    state_ids = {"Alabama":"01",
                 "Alaska":"02",
                 "Arizona":"04",
                 "Arkansas":"05",
                 "California":"06",
                 "Colorado":"08",
                 "Connecticut": "09",
                 "Delaware":"10",
                 "District of Columbia":"11",
                 "Florida":"12",
                 "Georgia":"13",
                 "Hawaii":"15",
                 "Idaho": "16",
                 "Illinois": "17",
                 "Indiana": "18",
                 "Iowa": "19",
                 "Kansas":"20",
                 "Kentucky":"21",
                 "Louisiana":"22",
                 "Maine":"23",
                 "Maryland":"24" ,
                 "Massachusetts":"25",
                 "Michigan":"26",
                 "Minnesota":"27",
                 "Mississippi":"28",
                 "Missouri": "29",
                 "Montana":"30",
                 "Nebraska":"31",
                 "Nevada": "32",
                 "New Hampshire":"33",
                 "New Jersey": "34",
                 "New Mexico": "35",
                "New York":"36",
                "North Carolina": "37",
                "North Dakota": "38",
                "Ohio":"39",
                "Oklahoma": "40",
                "Oregon": "41",
                "Pennsylvania": "42",
                "Rhode Island":"44",
                "South Carolina":"45",
                "South Dakota": "46",
                "Tennessee":"47",
                "Texas": "48",
                 "Utah":"49",
                 "Vermont":"50",
                 "Virginia":"51",
                 "Washington":"53",
                 "West Virginia": "54",
                 "Wisconsin":"55",
                 "Wyoming": "56"}

    candidate = mongo.db.pCandidate.find()
    state = mongo.db.pState.find()
    county = mongo.db.pCounty.find()
    county_ids = mongo.db.countyIds.find()

    all_data = [candidate, state, county, county_ids]

    return_list = []

    for dataset in all_data:

        list_cur = list(dataset)
        json_data = dumps(list_cur)
        return_list.append(json_data)
    
    # Pull only candidate data
    candidate_data = return_list[0]
    
    # Convert string of json to a json file
    candidate_json = json.loads(candidate_data)
    
    # Convert json file to data frame
    df = pd.DataFrame.from_records(candidate_json)
    
    # Filter data by our two candidates (Biden and Trump)
    candidate_df = df.loc[(df["candidate"] == "Joe Biden") | (df["candidate"] == "Donald Trump"),:]
    
    # Group data by states
    condensed_df = candidate_df.groupby(["state","candidate"]).sum()
    
    # Calculate Democrat win percentage
    i = 0         # 0 means Trump, 1 means Biden 
    count = 0
    finalJson = {}
    percentDem= {}
    x = 1 
       
    for index, row in condensed_df.iterrows():
        if i == 0:
            count = count + row["total_votes"]
            i = i + 1
        else:
            count = count + row["total_votes"]
            percent = row["total_votes"] / count
            state = row.name[0]
            state_id = state_ids.get(state)
            percentDem.update({state_id : percent})

            i = 0
            count = 0
            x= x + 1
    
    
    countyIds_data = return_list[3]
    countyIds_json = json.loads(countyIds_data)
    
    finalJson.update(percentDem)
    finalJson.update({"countyIDs": countyIds_data})
    
    return countyIds_json



#if __name__ == "__main__":
    #app.run(debug=True)

# %%
d = index()
d
# Out:
# '[{"_id": {"$oid": "60f0dc8fe3c510961b8b301b"}, "id ": 1000, "name": "Alabama"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b301c"}, "id ": 1001, "name": "Autauga"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b301d"}, "id ": 1003, "name": "Baldwin"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b301e"}, "id ": 1005, "name": "Barbour"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b301f"}, "id ": 1007, "name": "Bibb"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3020"}, "id ": 1009, "name": "Blount"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3021"}, "id ": 1011, "name": "Bullock"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3022"}, "id ": 1013, "name": "Butler"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3023"}, "id ": 1015, "name": "Calhoun"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3024"}, "id ": 1017, "name": "Chambers"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3025"}, "id ": 1019, "name": "Cherokee"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3026"}, "id ": 1021, "name": "Chilton"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3027"}, "id ": 1023, "name": "Choctaw"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3028"}, "id ": 1025, "name": "Clarke"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3029"}, "id ": 1027, "name": "Clay"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b302a"}, "id ": 1029, "name": "Cleburne"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b302b"}, "id ": 1031, "name": "Coffee"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b302c"}, "id ": 1033, "name": "Colbert"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b302d"}, "id ": 1035, "name": "Conecuh"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b302e"}, "id ": 1037, "name": "Coosa"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b302f"}, "id ": 1039, "name": "Covington"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3030"}, "id ": 1041, "name": "Crenshaw"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3031"}, "id ": 1043, "name": "Cullman"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3032"}, "id ": 1045, "name": "Dale"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3033"}, "id ": 1047, "name": "Dallas"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3034"}, "id ": 1049, "name": "De Kalb"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3035"}, "id ": 1051, "name": "Elmore"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3036"}, "id ": 1053, "name": "Escambia"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3037"}, "id ": 1055, "name": "Etowah"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3038"}, "id ": 1057, "name": "Fayette"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3039"}, "id ": 1059, "name": "Franklin"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b303a"}, "id ": 1061, "name": "Geneva"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b303b"}, "id ": 1063, "name": "Greene"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b303c"}, "id ": 1065, "name": "Hale"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b303d"}, "id ": 1067, "name": "Henry"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b303e"}, "id ": 1069, "name": "Houston"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b303f"}, "id ": 1071, "name": "Jackson"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3040"}, "id ": 1073, "name": "Jefferson"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3041"}, "id ": 1075, "name": "Lamar"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3042"}, "id ": 1077, "name": "Lauderdale"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3043"}, "id ": 1079, "name": "Lawrence"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3044"}, "id ": 1081, "name": "Lee"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3045"}, "id ": 1083, "name": "Limestone"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3046"}, "id ": 1085, "name": "Lowndes"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3047"}, "id ": 1087, "name": "Macon"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3048"}, "id ": 1089, "name": "Madison"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b3049"}, "id ": 1091, "name": "Marengo"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b304a"}, "id ": 1093, "name": "Marion"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b304b"}, "id ": 1095, "name": "Marshall"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b304c"}, "id ": 1097, "name": "Mobile"}, {"_id": {"$oid": "60f0dc8fe3c510961b8b304d"}, "id ": 1099, "name": ...

# %%
b = pd.DataFrame.from_records(d)

c = b.loc[(b["candidate"] == "Joe Biden") | (b["candidate"] == "Donald Trump"),:]

i = 0
count = 0
percentDem= []

for index, row in c.iterrows():
    if i == 0:
        count = count + row["total_votes"]
        i = i + 1
    else:
        count = count + row["total_votes"]
        
        percent = row["total_votes"] / count
        
        percentDem.append(percent)
        
        i = 0
        count = 0

percentDem

# %%
    candidate = mongo.db.pCandidate.find()
    state = mongo.db.pState.find()
    county = mongo.db.pCounty.find()

    all_data = [candidate, state, county]

    return_list = []

    for dataset in all_data:

        list_cur = list(dataset)
        json_data = dumps(list_cur)
        return_list.append(json_data)
    
    # Pull only candidate data
    candidate_data = return_list[0]
    
    # Convert string of json to a json file
    candidate_json = json.loads(candidate_data)
    
    # Convert json file to data frame
    df = pd.DataFrame.from_records(candidate_json)
    
    # Filter data by our two candidates (Biden and Trump)
    candidate_df = df.loc[(df["candidate"] == "Joe Biden") | (df["candidate"] == "Donald Trump"),:]
    
    # Group data by states
    condensed_df = candidate_df.groupby(["state","candidate"]).sum()
    
    condensed_df
# Out:
#                             total_votes   won
# state         candidate
# Alabama       Donald Trump      1441168  54.0
#               Joe Biden          849648  13.0
# Alaska        Donald Trump       189892  20.0
#               Joe Biden          153405  17.0
# Arizona       Donald Trump      1661686  10.0
# ...                                 ...   ...
# West Virginia Joe Biden          235984   0.0
# Wisconsin     Donald Trump      1610065  58.0
#               Joe Biden         1630673  14.0
# Wyoming       Donald Trump       193559  21.0
#               Joe Biden           73491   2.0
#
# [102 rows x 2 columns]

# %%
    for index, row in condensed_df.iterrows():
        print(row.name[0])
# Out:
# Alabama
# Alabama
# Alaska
# Alaska
# Arizona
# Arizona
# Arkansas
# Arkansas
# California
# California
# Colorado
# Colorado
# Connecticut
# Connecticut
# Delaware
# Delaware
# District of Columbia
# District of Columbia
# Florida
# Florida
# Georgia
# Georgia
# Hawaii
# Hawaii
# Idaho
# Idaho
# Illinois
# Illinois
# Indiana
# Indiana
# Iowa
# Iowa
# Kansas
# Kansas
# Kentucky
# Kentucky
# Louisiana
# Louisiana
# Maine
# Maine
# Maryland
# Maryland
# Massachusetts
# Massachusetts
# Michigan
# Michigan
# Minnesota
# Minnesota
# Mississippi
# Mississippi
# Missouri
# Missouri
# Montana
# Montana
# Nebraska
# Nebraska
# Nevada
# Nevada
# New Hampshire
# New Hampshire
# New Jersey
# New Jersey
# New Mexico
# New Mexico
# New York
# New York
# North Carolina
# North Carolina
# North Dakota
# North Dakota
# Ohio
# Ohio
# Oklahoma
# Oklahoma
# Oregon
# Oregon
# Pennsylvania
# Pennsylvania
# Rhode Island
# Rhode Island
# South Carolina
# South Carolina
# South Dakota
# South Dakota
# Tennessee
# Tennessee
# Texas
# Texas
# Utah
# Utah
# Vermont
# Vermont
# Virginia
# Virginia
# Washington
# Washington
# West Virginia
# West Virginia
# Wisconsin
# Wisconsin
# Wyoming
# Wyoming
