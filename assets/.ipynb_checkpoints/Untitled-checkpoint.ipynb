# %%
# Dependencies
from flask import Flask, render_template, redirect, Markup, jsonify
from flask_pymongo import PyMongo
from bson.json_util import dumps
import pymongo
from flask_cors import CORS
import pandas as pd
import json

# %%
app = Flask(__name__)

CORS(app, support_credentials = True)

# Use flask_pymongo to set up mongo connection
app.config["MONGO_URI"] = "mongodb://localhost:27017/election2020"
mongo = PyMongo(app)

# %%
# create route that rendrs index.html template
# @app.route("/")

def getData():
    # Pull data from Mongo
    candidate = mongo.db.pCandidate.find()
    state = mongo.db.pState.find()
    county = mongo.db.pCounty.find()
    county_IDs = mongo.db.countyIds.find()

    all_data = [candidate, state, county, county_IDs ]

    return all_data

def index():   
    
    # Create dictionary to for topojson state ids
    state_ids = {"Alabama": "01",
                 "Alaska": "02",
                 "Arizona": "04",
                 "Arkansas": "05",
                 "California": "06",
                 "Colorado": "08",
                 "Connecticut": "09",
                 "Delaware": "10",
                 "District of Columbia": "11",
                 "Florida": "12",
                 "Georgia": "13",
                 "Hawaii": "15",
                 "Idaho": "16",
                 "Illinois": "17",
                 "Indiana": "18",
                 "Iowa": "19",
                 "Kansas": "20",
                 "Kentucky": "21",
                 "Louisiana": "22",
                 "Maine": "23",
                 "Maryland": "24",
                 "Massachusetts": "25",
                 "Michigan": "26",
                 "Minnesota": "27",
                 "Mississippi": "28",
                 "Missouri": "29",
                 "Montana": "30",
                 "Nebraska": "31",
                 "Nevada": "32",
                 "New Hampshire": "33",
                 "New Jersey": "34",
                 "New Mexico": "35",
                 "New York": "36",
                 "North Carolina": "37",
                 "North Dakota": "38",
                 "Ohio": "39",
                 "Oklahoma": "40",
                 "Oregon": "41",
                 "Pennsylvania": "42",
                 "Rhode Island": "44",
                 "South Carolina": "45",
                 "South Dakota": "46",
                 "Tennessee": "47",
                 "Texas": "48",
                 "Utah": "49",
                 "Vermont": "50",
                 "Virginia": "51",
                 "Washington": "53",
                 "West Virginia": "54",
                 "Wisconsin": "55",
                 "Wyoming": "56"}

    all_data = getData()

    return_list = []

    for dataset in all_data:

        list_cur = list(dataset)
        json_data = dumps(list_cur)
        return_list.append(json_data)

    # Pull only candidate data
    candidate_data = return_list[0]

    # Convert string of json to a json file
    candidate_json = json.loads(candidate_data)

    # Convert json file to data frame
    df = pd.DataFrame.from_records(candidate_json)

    # Filter data by our two candidates (Biden and Trump)
    candidate_df = df.loc[(df["candidate"] == "Joe Biden") | (
        df["candidate"] == "Donald Trump"), :]

    # Group data by states
    condensed_df = candidate_df.groupby(["state", "candidate"]).sum()

    # Calculate Democrat win percentage
    i = 0         # 0 means Trump, 1 means Biden
    count = 0
    finalJson = {}
    percentDem = {}
    counties = {}
    x = 1 
       
    for index, row in condensed_df.iterrows():
        if i == 0:
            count = count + row["total_votes"]
            i = i + 1
        else:
            count = count + row["total_votes"]
            percent = row["total_votes"] / count
            state = row.name[0]
            state_id = state_ids.get(state)

            state_info = {state_id: percent}

            percentDem.update(state_info)

            i = 0
            count = 0
            x = x + 1

    countyIds_data = return_list[2]
    countyIds_json = json.loads(countyIds_data)

    for element in countyIds_json:
        ids = element.get("id")
        names = element.get("name")
        
        counties.update({ids:names})




    
    finalJson.update({"percentDem": percentDem})
    finalJson.update({"countyIDs": counties})
    
    return countyIds_json



#if __name__ == "__main__":
    #app.run(debug=True)

# %%
d = index()
d
# Out:
# [{'_id': {'$oid': '60f105bfe3c510961b8bbae9'},
#   'state': 'Delaware',
#   'county': 'Kent County',
#   'current_votes': 87025,
#   'total_votes': 87025,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaea'},
#   'state': 'Delaware',
#   'county': 'New Castle County',
#   'current_votes': 287633,
#   'total_votes': 287633,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaeb'},
#   'state': 'Delaware',
#   'county': 'Sussex County',
#   'current_votes': 129352,
#   'total_votes': 129352,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaec'},
#   'state': 'District of Columbia',
#   'county': 'District of Columbia',
#   'current_votes': 41681,
#   'total_votes': 41681,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaed'},
#   'state': 'District of Columbia',
#   'county': 'Ward 2',
#   'current_votes': 32881,
#   'total_votes': 32881,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaee'},
#   'state': 'District of Columbia',
#   'county': 'Ward 3',
#   'current_votes': 44231,
#   'total_votes': 44231,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaef'},
#   'state': 'District of Columbia',
#   'county': 'Ward 4',
#   'current_votes': 45296,
#   'total_votes': 45296,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf0'},
#   'state': 'District of Columbia',
#   'county': 'Ward 5',
#   'current_votes': 46107,
#   'total_votes': 46107,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf1'},
#   'state': 'District of Columbia',
#   'county': 'Ward 6',
#   'current_votes': 62918,
#   'total_votes': 62918,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf2'},
#   'state': 'District of Columbia',
#   'county': 'Ward 7',
#   'current_votes': 38384,
#   'total_votes': 38384,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf3'},
#   'state': 'District of Columbia',
#   'county': 'Ward 8',
#   'current_votes': 32858,
#   'total_votes': 32858,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf4'},
#   'state': 'Florida',
#   'county': 'Alachua County',
#   'current_votes': 142604,
#   'total_votes': 142604,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf5'},
#   'state': 'Florida',
#   'county': 'Baker County',
#   'current_votes': 14059,
#   'total_votes': 14059,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf6'},
#   'state': 'Florida',
#   'county': 'Bay County',
#   'current_votes': 93024,
#   'total_votes': 93024,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf7'},
#   'state': 'Florida',
#   'county': 'Bradford County',
#   'current_votes': 13632,
#   'total_votes': 13632,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf8'},
#   'state': 'Florida',
#   'county': 'Brevard County',
#   'current_votes': 360764,
#   'total_votes': 360764,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaf9'},
#   'state': 'Florida',
#   'county': 'Broward County',
#   'current_votes': 957672,
#   'total_votes': 957672,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbafa'},
#   'state': 'Florida',
#   'county': 'Calhoun County',
#   'current_votes': 6526,
#   'total_votes': 6526,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbafb'},
#   'state': 'Florida',
#   'county': 'Charlotte County',
#   'current_votes': 116340,
#   'total_votes': 116340,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbafc'},
#   'state': 'Florida',
#   'county': 'Citrus County',
#   'current_votes': 93208,
#   'total_votes': 93208,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbafd'},
#   'state': 'Florida',
#   'county': 'Clay County',
#   'current_votes': 124405,
#   'total_votes': 124405,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbafe'},
#   'state': 'Florida',
#   'county': 'Collier County',
#   'current_votes': 207818,
#   'total_votes': 207818,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbaff'},
#   'state': 'Florida',
#   'county': 'Columbia County',
#   'current_votes': 33042,
#   'total_votes': 33042,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb00'},
#   'state': 'Florida',
#   'county': 'DeSoto County',
#   'current_votes': 12659,
#   'total_votes': 12659,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb01'},
#   'state': 'Florida',
#   'county': 'Dixie County',
#   'current_votes': 8167,
#   'total_votes': 8167,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb02'},
#   'state': 'Florida',
#   'county': 'Duval County',
#   'current_votes': 492820,
#   'total_votes': 492820,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb03'},
#   'state': 'Florida',
#   'county': 'Escambia County',
#   'current_votes': 170372,
#   'total_votes': 170372,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb04'},
#   'state': 'Florida',
#   'county': 'Flagler County',
#   'current_votes': 71716,
#   'total_votes': 71716,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb05'},
#   'state': 'Florida',
#   'county': 'Franklin County',
#   'current_votes': 6849,
#   'total_votes': 6849,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb06'},
#   'state': 'Florida',
#   'county': 'Gadsden County',
#   'current_votes': 23762,
#   'total_votes': 23762,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb07'},
#   'state': 'Florida',
#   'county': 'Gilchrist County',
#   'current_votes': 9685,
#   'total_votes': 9685,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb08'},
#   'state': 'Florida',
#   'county': 'Glades County',
#   'current_votes': 5193,
#   'total_votes': 5193,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb09'},
#   'state': 'Florida',
#   'county': 'Gulf County',
#   'current_votes': 8163,
#   'total_votes': 8163,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb0a'},
#   'state': 'Florida',
#   'county': 'Hamilton County',
#   'current_votes': 5830,
#   'total_votes': 5830,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb0b'},
#   'state': 'Florida',
#   'county': 'Hardee County',
#   'current_votes': 8485,
#   'total_votes': 8485,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb0c'},
#   'state': 'Florida',
#   'county': 'Hendry County',
#   'current_votes': 12940,
#   'total_votes': 12940,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb0d'},
#   'state': 'Florida',
#   'county': 'Hernando County',
#   'current_votes': 108922,
#   'total_votes': 108922,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb0e'},
#   'state': 'Florida',
#   'county': 'Highlands County',
#   'current_votes': 52170,
#   'total_votes': 52170,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb0f'},
#   'state': 'Florida',
#   'county': 'Hillsborough County',
#   'current_votes': 712063,
#   'total_votes': 712063,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb10'},
#   'state': 'Florida',
#   'county': 'Holmes County',
#   'current_votes': 9068,
#   'total_votes': 9068,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb11'},
#   'state': 'Florida',
#   'county': 'Indian River County',
#   'current_votes': 97484,
#   'total_votes': 97484,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb12'},
#   'state': 'Florida',
#   'county': 'Jackson County',
#   'current_votes': 22419,
#   'total_votes': 22419,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb13'},
#   'state': 'Florida',
#   'county': 'Jefferson County',
#   'current_votes': 8451,
#   'total_votes': 8451,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb14'},
#   'state': 'Florida',
#   'county': 'Lafayette County',
#   'current_votes': 3658,
#   'total_votes': 3658,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb15'},
#   'state': 'Florida',
#   'county': 'Lake County',
#   'current_votes': 211314,
#   'total_votes': 211314,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb16'},
#   'state': 'Florida',
#   'county': 'Lee County',
#   'current_votes': 393899,
#   'total_votes': 393899,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb17'},
#   'state': 'Florida',
#   'county': 'Leon County',
#   'current_votes': 162929,
#   'total_votes': 162929,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb18'},
#   'state': 'Florida',
#   'county': 'Levy County',
#   'current_votes': 23145,
#   'total_votes': 23145,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb19'},
#   'state': 'Florida',
#   'county': 'Liberty County',
#   'current_votes': 3561,
#   'total_votes': 3561,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb1a'},
#   'state': 'Florida',
#   'county': 'Madison County',
#   'current_votes': 9380,
#   'total_votes': 9380,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb1b'},
#   'state': 'Florida',
#   'county': 'Manatee County',
#   'current_votes': 216958,
#   'total_votes': 216958,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb1c'},
#   'state': 'Florida',
#   'county': 'Marion County',
#   'current_votes': 204376,
#   'total_votes': 204376,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb1d'},
#   'state': 'Florida',
#   'county': 'Martin County',
#   'current_votes': 98726,
#   'total_votes': 98726,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb1e'},
#   'state': 'Florida',
#   'county': 'Miami-Dade County',
#   'current_votes': 1156816,
#   'total_votes': 1156816,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb1f'},
#   'state': 'Florida',
#   'county': 'Monroe County',
#   'current_votes': 48029,
#   'total_votes': 48029,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb20'},
#   'state': 'Florida',
#   'county': 'Nassau County',
#   'current_votes': 58811,
#   'total_votes': 58811,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb21'},
#   'state': 'Florida',
#   'county': 'Okaloosa County',
#   'current_votes': 116373,
#   'total_votes': 116373,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb22'},
#   'state': 'Florida',
#   'county': 'Okeechobee County',
#   'current_votes': 15954,
#   'total_votes': 15954,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb23'},
#   'state': 'Florida',
#   'county': 'Orange County',
#   'current_votes': 647403,
#   'total_votes': 647403,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb24'},
#   'state': 'Florida',
#   'county': 'Osceola County',
#   'current_votes': 172436,
#   'total_votes': 172436,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb25'},
#   'state': 'Florida',
#   'county': 'Palm Beach County',
#   'current_votes': 773158,
#   'total_votes': 773158,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb26'},
#   'state': 'Florida',
#   'county': 'Pasco County',
#   'current_votes': 301970,
#   'total_votes': 301970,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb27'},
#   'state': 'Florida',
#   'county': 'Pinellas County',
#   'current_votes': 559715,
#   'total_votes': 559715,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb28'},
#   'state': 'Florida',
#   'county': 'Polk County',
#   'current_votes': 343256,
#   'total_votes': 343256,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb29'},
#   'state': 'Florida',
#   'county': 'Putnam County',
#   'current_votes': 36373,
#   'total_votes': 36373,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb2a'},
#   'state': 'Florida',
#   'county': 'St. Johns County',
#   'current_votes': 176622,
#   'total_votes': 176622,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb2b'},
#   'state': 'Florida',
#   'county': 'St. Lucie County',
#   'current_votes': 172169,
#   'total_votes': 172169,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb2c'},
#   'state': 'Florida',
#   'county': 'Santa Rosa County',
#   'current_votes': 106928,
#   'total_votes': 106928,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb2d'},
#   'state': 'Florida',
#   'county': 'Sarasota County',
#   'current_votes': 270575,
#   'total_votes': 270575,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb2e'},
#   'state': 'Florida',
#   'county': 'Seminole County',
#   'current_votes': 260815,
#   'total_votes': 260815,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb2f'},
#   'state': 'Florida',
#   'county': 'Sumter County',
#   'current_votes': 92485,
#   'total_votes': 92485,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb30'},
#   'state': 'Florida',
#   'county': 'Suwannee County',
#   'current_votes': 21057,
#   'total_votes': 21057,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb31'},
#   'state': 'Florida',
#   'county': 'Taylor County',
#   'current_votes': 10127,
#   'total_votes': 10127,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb32'},
#   'state': 'Florida',
#   'county': 'Union County',
#   'current_votes': 6245,
#   'total_votes': 6245,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb33'},
#   'state': 'Florida',
#   'county': 'Volusia County',
#   'current_votes': 307439,
#   'total_votes': 307439,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb34'},
#   'state': 'Florida',
#   'county': 'Wakulla County',
#   'current_votes': 18404,
#   'total_votes': 18404,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb35'},
#   'state': 'Florida',
#   'county': 'Walton County',
#   'current_votes': 43711,
#   'total_votes': 43711,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb36'},
#   'state': 'Florida',
#   'county': 'Washington County',
#   'current_votes': 12327,
#   'total_votes': 12327,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb37'},
#   'state': 'Georgia',
#   'county': 'Appling County',
#   'current_votes': 8390,
#   'total_votes': 8341,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb38'},
#   'state': 'Georgia',
#   'county': 'Atkinson County',
#   'current_votes': 3155,
#   'total_votes': 3155,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb39'},
#   'state': 'Georgia',
#   'county': 'Bacon County',
#   'current_votes': 4667,
#   'total_votes': 4668,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb3a'},
#   'state': 'Georgia',
#   'county': 'Baker County',
#   'current_votes': 1555,
#   'total_votes': 1555,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb3b'},
#   'state': 'Georgia',
#   'county': 'Baldwin County',
#   'current_votes': 18251,
#   'total_votes': 18251,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb3c'},
#   'state': 'Georgia',
#   'county': 'Banks County',
#   'current_votes': 8801,
#   'total_votes': 8801,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb3d'},
#   'state': 'Georgia',
#   'county': 'Barrow County',
#   'current_votes': 37921,
#   'total_votes': 38017,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb3e'},
#   'state': 'Georgia',
#   'county': 'Bartow County',
#   'current_votes': 50464,
#   'total_votes': 50467,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb3f'},
#   'state': 'Georgia',
#   'county': 'Ben Hill County',
#   'current_votes': 6564,
#   'total_votes': 6560,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb40'},
#   'state': 'Georgia',
#   'county': 'Berrien County',
#   'current_votes': 7743,
#   'total_votes': 7743,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb41'},
#   'state': 'Georgia',
#   'county': 'Bibb County',
#   'current_votes': 70714,
#   'total_votes': 70802,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb42'},
#   'state': 'Georgia',
#   'county': 'Bleckley County',
#   'current_votes': 5708,
#   'total_votes': 5706,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb43'},
#   'state': 'Georgia',
#   'county': 'Brantley County',
#   'current_votes': 7749,
#   'total_votes': 7746,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb44'},
#   'state': 'Georgia',
#   'county': 'Brooks County',
#   'current_votes': 7101,
#   'total_votes': 7100,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb45'},
#   'state': 'Georgia',
#   'county': 'Bryan County',
#   'current_votes': 21335,
#   'total_votes': 21340,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb46'},
#   'state': 'Georgia',
#   'county': 'Bulloch County',
#   'current_votes': 30090,
#   'total_votes': 30084,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb47'},
#   'state': 'Georgia',
#   'county': 'Burke County',
#   'current_votes': 10683,
#   'total_votes': 10684,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb48'},
#   'state': 'Georgia',
#   'county': 'Butts County',
#   'current_votes': 11771,
#   'total_votes': 11789,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb49'},
#   'state': 'Georgia',
#   'county': 'Calhoun County',
#   'current_votes': 2198,
#   'total_votes': 2194,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb4a'},
#   'state': 'Georgia',
#   'county': 'Camden County',
#   'current_votes': 23686,
#   'total_votes': 23688,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb4b'},
#   'state': 'Georgia',
#   'county': 'Candler County',
#   'current_votes': 4431,
#   'total_votes': 4432,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb4c'},
#   'state': 'Georgia',
#   'county': 'Carroll County',
#   'current_votes': 54472,
#   'total_votes': 54474,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb4d'},
#   'state': 'Georgia',
#   'county': 'Catoosa County',
#   'current_votes': 32593,
#   'total_votes': 32692,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb4e'},
#   'state': 'Georgia',
#   'county': 'Charlton County',
#   'current_votes': 4568,
#   'total_votes': 4566,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb4f'},
#   'state': 'Georgia',
#   'county': 'Chatham County',
#   'current_votes': 133408,
#   'total_votes': 133420,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb50'},
#   'state': 'Georgia',
#   'county': 'Chattahoochee County',
#   'current_votes': 1582,
#   'total_votes': 1590,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb51'},
#   'state': 'Georgia',
#   'county': 'Chattooga County',
#   'current_votes': 10050,
#   'total_votes': 10050,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb52'},
#   'state': 'Georgia',
#   'county': 'Cherokee County',
#   'current_votes': 144815,
#   'total_votes': 144830,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb53'},
#   'state': 'Georgia',
#   'county': 'Clarke County',
#   'current_votes': 51346,
#   'total_votes': 51218,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb54'},
#   'state': 'Georgia',
#   'county': 'Clay County',
#   'current_votes': 1435,
#   'total_votes': 1434,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb55'},
#   'state': 'Georgia',
#   'county': 'Clayton County',
#   'current_votes': 112330,
#   'total_votes': 112344,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb56'},
#   'state': 'Georgia',
#   'county': 'Clinch County',
#   'current_votes': 2861,
#   'total_votes': 2864,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb57'},
#   'state': 'Georgia',
#   'county': 'Cobb County',
#   'current_votes': 393728,
#   'total_votes': 393744,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb58'},
#   'state': 'Georgia',
#   'county': 'Coffee County',
#   'current_votes': 15214,
#   'total_votes': 15214,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb59'},
#   'state': 'Georgia',
#   'county': 'Colquitt County',
#   'current_votes': 16086,
#   'total_votes': 16083,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb5a'},
#   'state': 'Georgia',
#   'county': 'Columbia County',
#   'current_votes': 80575,
#   'total_votes': 80579,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb5b'},
#   'state': 'Georgia',
#   'county': 'Cook County',
#   'current_votes': 7035,
#   'total_votes': 7035,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb5c'},
#   'state': 'Georgia',
#   'county': 'Coweta County',
#   'current_votes': 76799,
#   'total_votes': 76799,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb5d'},
#   'state': 'Georgia',
#   'county': 'Crawford County',
#   'current_votes': 6102,
#   'total_votes': 6102,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb5e'},
#   'state': 'Georgia',
#   'county': 'Crisp County',
#   'current_votes': 8033,
#   'total_votes': 8052,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb5f'},
#   'state': 'Georgia',
#   'county': 'Dade County',
#   'current_votes': 7434,
#   'total_votes': 7434,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb60'},
#   'state': 'Georgia',
#   'county': 'Dawson County',
#   'current_votes': 16081,
#   'total_votes': 16081,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb61'},
#   'state': 'Georgia',
#   'county': 'Decatur County',
#   'current_votes': 11625,
#   'total_votes': 11627,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb62'},
#   'state': 'Georgia',
#   'county': 'DeKalb County',
#   'current_votes': 370746,
#   'total_votes': 370675,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb63'},
#   'state': 'Georgia',
#   'county': 'Dodge County',
#   'current_votes': 8071,
#   'total_votes': 8070,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb64'},
#   'state': 'Georgia',
#   'county': 'Dooly County',
#   'current_votes': 4105,
#   'total_votes': 4105,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb65'},
#   'state': 'Georgia',
#   'county': 'Dougherty County',
#   'current_votes': 35287,
#   'total_votes': 35311,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb66'},
#   'state': 'Georgia',
#   'county': 'Douglas County',
#   'current_votes': 69106,
#   'total_votes': 69097,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb67'},
#   'state': 'Georgia',
#   'county': 'Early County',
#   'current_votes': 5188,
#   'total_votes': 5187,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb68'},
#   'state': 'Georgia',
#   'county': 'Echols County',
#   'current_votes': 1441,
#   'total_votes': 1441,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb69'},
#   'state': 'Georgia',
#   'county': 'Effingham County',
#   'current_votes': 31571,
#   'total_votes': 31624,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb6a'},
#   'state': 'Georgia',
#   'county': 'Elbert County',
#   'current_votes': 9171,
#   'total_votes': 9171,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb6b'},
#   'state': 'Georgia',
#   'county': 'Emanuel County',
#   'current_votes': 9505,
#   'total_votes': 9501,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb6c'},
#   'state': 'Georgia',
#   'county': 'Evans County',
#   'current_votes': 4247,
#   'total_votes': 4247,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb6d'},
#   'state': 'Georgia',
#   'county': 'Fannin County',
#   'current_votes': 14849,
#   'total_votes': 14850,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb6e'},
#   'state': 'Georgia',
#   'county': 'Fayette County',
#   'current_votes': 71994,
#   'total_votes': 71993,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb6f'},
#   'state': 'Georgia',
#   'county': 'Floyd County',
#   'current_votes': 41341,
#   'total_votes': 38588,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb70'},
#   'state': 'Georgia',
#   'county': 'Forsyth County',
#   'current_votes': 129311,
#   'total_votes': 129305,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb71'},
#   'state': 'Georgia',
#   'county': 'Franklin County',
#   'current_votes': 10765,
#   'total_votes': 10786,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb72'},
#   'state': 'Georgia',
#   'county': 'Fulton County',
#   'current_votes': 523779,
#   'total_votes': 524659,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb73'},
#   'state': 'Georgia',
#   'county': 'Gilmer County',
#   'current_votes': 16525,
#   'total_votes': 16525,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb74'},
#   'state': 'Georgia',
#   'county': 'Glascock County',
#   'current_votes': 1565,
#   'total_votes': 1566,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb75'},
#   'state': 'Georgia',
#   'county': 'Glynn County',
#   'current_votes': 41988,
#   'total_votes': 41984,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb76'},
#   'state': 'Georgia',
#   'county': 'Gordon County',
#   'current_votes': 24033,
#   'total_votes': 24033,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb77'},
#   'state': 'Georgia',
#   'county': 'Grady County',
#   'current_votes': 10707,
#   'total_votes': 10707,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb78'},
#   'state': 'Georgia',
#   'county': 'Greene County',
#   'current_votes': 11244,
#   'total_votes': 11247,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb79'},
#   'state': 'Georgia',
#   'county': 'Gwinnett County',
#   'current_votes': 414023,
#   'total_votes': 413865,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb7a'},
#   'state': 'Georgia',
#   'county': 'Habersham County',
#   'current_votes': 20431,
#   'total_votes': 20432,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb7b'},
#   'state': 'Georgia',
#   'county': 'Hall County',
#   'current_votes': 90537,
#   'total_votes': 90523,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb7c'},
#   'state': 'Georgia',
#   'county': 'Hancock County',
#   'current_votes': 4153,
#   'total_votes': 4165,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb7d'},
#   'state': 'Georgia',
#   'county': 'Haralson County',
#   'current_votes': 14246,
#   'total_votes': 14272,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb7e'},
#   'state': 'Georgia',
#   'county': 'Harris County',
#   'current_votes': 19991,
#   'total_votes': 19991,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb7f'},
#   'state': 'Georgia',
#   'county': 'Hart County',
#   'current_votes': 12728,
#   'total_votes': 12727,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb80'},
#   'state': 'Georgia',
#   'county': 'Heard County',
#   'current_votes': 5394,
#   'total_votes': 5397,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb81'},
#   'state': 'Georgia',
#   'county': 'Henry County',
#   'current_votes': 122998,
#   'total_votes': 122742,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb82'},
#   'state': 'Georgia',
#   'county': 'Houston County',
#   'current_votes': 74838,
#   'total_votes': 74823,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb83'},
#   'state': 'Georgia',
#   'county': 'Irwin County',
#   'current_votes': 4168,
#   'total_votes': 4168,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb84'},
#   'state': 'Georgia',
#   'county': 'Jackson County',
#   'current_votes': 37675,
#   'total_votes': 37670,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb85'},
#   'state': 'Georgia',
#   'county': 'Jasper County',
#   'current_votes': 7644,
#   'total_votes': 7644,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb86'},
#   'state': 'Georgia',
#   'county': 'Jeff Davis County',
#   'current_votes': 5771,
#   'total_votes': 5771,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb87'},
#   'state': 'Georgia',
#   'county': 'Jefferson County',
#   'current_votes': 7639,
#   'total_votes': 7642,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb88'},
#   'state': 'Georgia',
#   'county': 'Jenkins County',
#   'current_votes': 3455,
#   'total_votes': 3455,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb89'},
#   'state': 'Georgia',
#   'county': 'Johnson County',
#   'current_votes': 4100,
#   'total_votes': 4100,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb8a'},
#   'state': 'Georgia',
#   'county': 'Jones County',
#   'current_votes': 14934,
#   'total_votes': 14966,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb8b'},
#   'state': 'Georgia',
#   'county': 'Lamar County',
#   'current_votes': 9045,
#   'total_votes': 9039,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb8c'},
#   'state': 'Georgia',
#   'county': 'Lanier County',
#   'current_votes': 3576,
#   'total_votes': 3576,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb8d'},
#   'state': 'Georgia',
#   'county': 'Laurens County',
#   'current_votes': 22731,
#   'total_votes': 22729,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb8e'},
#   'state': 'Georgia',
#   'county': 'Lee County',
#   'current_votes': 16714,
#   'total_votes': 16714,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb8f'},
#   'state': 'Georgia',
#   'county': 'Liberty County',
#   'current_votes': 21394,
#   'total_votes': 21389,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb90'},
#   'state': 'Georgia',
#   'county': 'Lincoln County',
#   'current_votes': 4641,
#   'total_votes': 4650,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb91'},
#   'state': 'Georgia',
#   'county': 'Long County',
#   'current_votes': 5657,
#   'total_votes': 5656,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb92'},
#   'state': 'Georgia',
#   'county': 'Lowndes County',
#   'current_votes': 46355,
#   'total_votes': 46355,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb93'},
#   'state': 'Georgia',
#   'county': 'Lumpkin County',
#   'current_votes': 15531,
#   'total_votes': 15531,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb94'},
#   'state': 'Georgia',
#   'county': 'McDuffie County',
#   'current_votes': 10455,
#   'total_votes': 10455,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb95'},
#   'state': 'Georgia',
#   'county': 'McIntosh County',
#   'current_votes': 6696,
#   'total_votes': 6696,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb96'},
#   'state': 'Georgia',
#   'county': 'Macon County',
#   'current_votes': 4663,
#   'total_votes': 4662,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb97'},
#   'state': 'Georgia',
#   'county': 'Madison County',
#   'current_votes': 14937,
#   'total_votes': 14937,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb98'},
#   'state': 'Georgia',
#   'county': 'Marion County',
#   'current_votes': 3625,
#   'total_votes': 3624,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb99'},
#   'state': 'Georgia',
#   'county': 'Meriwether County',
#   'current_votes': 10877,
#   'total_votes': 10877,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb9a'},
#   'state': 'Georgia',
#   'county': 'Miller County',
#   'current_votes': 2834,
#   'total_votes': 2835,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb9b'},
#   'state': 'Georgia',
#   'county': 'Mitchell County',
#   'current_votes': 8962,
#   'total_votes': 8963,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb9c'},
#   'state': 'Georgia',
#   'county': 'Monroe County',
#   'current_votes': 15590,
#   'total_votes': 15592,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb9d'},
#   'state': 'Georgia',
#   'county': 'Montgomery County',
#   'current_votes': 3967,
#   'total_votes': 3966,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb9e'},
#   'state': 'Georgia',
#   'county': 'Morgan County',
#   'current_votes': 11706,
#   'total_votes': 11707,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbb9f'},
#   'state': 'Georgia',
#   'county': 'Murray County',
#   'current_votes': 15389,
#   'total_votes': 15389,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba0'},
#   'state': 'Georgia',
#   'county': 'Muscogee County',
#   'current_votes': 80514,
#   'total_votes': 80543,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba1'},
#   'state': 'Georgia',
#   'county': 'Newton County',
#   'current_votes': 54234,
#   'total_votes': 54239,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba2'},
#   'state': 'Georgia',
#   'county': 'Oconee County',
#   'current_votes': 25168,
#   'total_votes': 25168,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba3'},
#   'state': 'Georgia',
#   'county': 'Oglethorpe County',
#   'current_votes': 8133,
#   'total_votes': 8131,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba4'},
#   'state': 'Georgia',
#   'county': 'Paulding County',
#   'current_votes': 85372,
#   'total_votes': 85385,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba5'},
#   'state': 'Georgia',
#   'county': 'Peach County',
#   'current_votes': 12553,
#   'total_votes': 12545,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba6'},
#   'state': 'Georgia',
#   'county': 'Pickens County',
#   'current_votes': 17167,
#   'total_votes': 17116,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba7'},
#   'state': 'Georgia',
#   'county': 'Pierce County',
#   'current_votes': 9047,
#   'total_votes': 9048,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba8'},
#   'state': 'Georgia',
#   'county': 'Pike County',
#   'current_votes': 10720,
#   'total_votes': 10720,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbba9'},
#   'state': 'Georgia',
#   'county': 'Polk County',
#   'current_votes': 17396,
#   'total_votes': 17399,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbaa'},
#   'state': 'Georgia',
#   'county': 'Pulaski County',
#   'current_votes': 4081,
#   'total_votes': 4059,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbab'},
#   'state': 'Georgia',
#   'county': 'Putnam County',
#   'current_votes': 11855,
#   'total_votes': 11855,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbac'},
#   'state': 'Georgia',
#   'county': 'Quitman County',
#   'current_votes': 1106,
#   'total_votes': 1106,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbad'},
#   'state': 'Georgia',
#   'county': 'Rabun County',
#   'current_votes': 9568,
#   'total_votes': 9568,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbae'},
#   'state': 'Georgia',
#   'county': 'Randolph County',
#   'current_votes': 3073,
#   'total_votes': 3074,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbaf'},
#   'state': 'Georgia',
#   'county': 'Richmond County',
#   'current_votes': 87009,
#   'total_votes': 87016,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb0'},
#   'state': 'Georgia',
#   'county': 'Rockdale County',
#   'current_votes': 44681,
#   'total_votes': 44686,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb1'},
#   'state': 'Georgia',
#   'county': 'Schley County',
#   'current_votes': 2275,
#   'total_votes': 2275,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb2'},
#   'state': 'Georgia',
#   'county': 'Screven County',
#   'current_votes': 6627,
#   'total_votes': 6628,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb3'},
#   'state': 'Georgia',
#   'county': 'Seminole County',
#   'current_votes': 3888,
#   'total_votes': 3884,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb4'},
#   'state': 'Georgia',
#   'county': 'Spalding County',
#   'current_votes': 30211,
#   'total_votes': 30116,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb5'},
#   'state': 'Georgia',
#   'county': 'Stephens County',
#   'current_votes': 11885,
#   'total_votes': 11885,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb6'},
#   'state': 'Georgia',
#   'county': 'Stewart County',
#   'current_votes': 1990,
#   'total_votes': 1990,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb7'},
#   'state': 'Georgia',
#   'county': 'Sumter County',
#   'current_votes': 12148,
#   'total_votes': 12150,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb8'},
#   'state': 'Georgia',
#   'county': 'Talbot County',
#   'current_votes': 3522,
#   'total_votes': 3522,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbb9'},
#   'state': 'Georgia',
#   'county': 'Taliaferro County',
#   'current_votes': 928,
#   'total_votes': 928,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbba'},
#   'state': 'Georgia',
#   'county': 'Tattnall County',
#   'current_votes': 8185,
#   'total_votes': 8183,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbbb'},
#   'state': 'Georgia',
#   'county': 'Taylor County',
#   'current_votes': 3842,
#   'total_votes': 3839,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbbc'},
#   'state': 'Georgia',
#   'county': 'Telfair County',
#   'current_votes': 4334,
#   'total_votes': 4333,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbbd'},
#   'state': 'Georgia',
#   'county': 'Terrell County',
#   'current_votes': 4416,
#   'total_votes': 4416,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbbe'},
#   'state': 'Georgia',
#   'county': 'Thomas County',
#   'current_votes': 21872,
#   'total_votes': 21853,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbbf'},
#   'state': 'Georgia',
#   'county': 'Tift County',
#   'current_votes': 16279,
#   'total_votes': 16283,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc0'},
#   'state': 'Georgia',
#   'county': 'Toombs County',
#   'current_votes': 10914,
#   'total_votes': 10914,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc1'},
#   'state': 'Georgia',
#   'county': 'Towns County',
#   'current_votes': 7979,
#   'total_votes': 7979,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc2'},
#   'state': 'Georgia',
#   'county': 'Treutlen County',
#   'current_votes': 3077,
#   'total_votes': 3077,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc3'},
#   'state': 'Georgia',
#   'county': 'Troup County',
#   'current_votes': 30047,
#   'total_votes': 30059,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc4'},
#   'state': 'Georgia',
#   'county': 'Turner County',
#   'current_votes': 3791,
#   'total_votes': 3792,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc5'},
#   'state': 'Georgia',
#   'county': 'Twiggs County',
#   'current_votes': 4444,
#   'total_votes': 4444,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc6'},
#   'state': 'Georgia',
#   'county': 'Union County',
#   'current_votes': 15558,
#   'total_votes': 15592,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc7'},
#   'state': 'Georgia',
#   'county': 'Upson County',
#   'current_votes': 12905,
#   'total_votes': 12905,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc8'},
#   'state': 'Georgia',
#   'county': 'Walker County',
#   'current_votes': 29354,
#   'total_votes': 29436,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbc9'},
#   'state': 'Georgia',
#   'county': 'Walton County',
#   'current_votes': 51093,
#   'total_votes': 50812,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbca'},
#   'state': 'Georgia',
#   'county': 'Ware County',
#   'current_votes': 14189,
#   'total_votes': 14296,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbcb'},
#   'state': 'Georgia',
#   'county': 'Warren County',
#   'current_votes': 2650,
#   'total_votes': 2681,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbcc'},
#   'state': 'Georgia',
#   'county': 'Washington County',
#   'current_votes': 9477,
#   'total_votes': 9459,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbcd'},
#   'state': 'Georgia',
#   'county': 'Wayne County',
#   'current_votes': 12779,
#   'total_votes': 12778,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbce'},
#   'state': 'Georgia',
#   'county': 'Webster County',
#   'current_votes': 1391,
#   'total_votes': 1390,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbcf'},
#   'state': 'Georgia',
#   'county': 'Wheeler County',
#   'current_votes': 2285,
#   'total_votes': 2285,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd0'},
#   'state': 'Georgia',
#   'county': 'White County',
#   'current_votes': 14816,
#   'total_votes': 14816,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd1'},
#   'state': 'Georgia',
#   'county': 'Whitfield County',
#   'current_votes': 36766,
#   'total_votes': 36746,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd2'},
#   'state': 'Georgia',
#   'county': 'Wilcox County',
#   'current_votes': 3279,
#   'total_votes': 3281,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd3'},
#   'state': 'Georgia',
#   'county': 'Wilkes County',
#   'current_votes': 5030,
#   'total_votes': 5029,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd4'},
#   'state': 'Georgia',
#   'county': 'Wilkinson County',
#   'current_votes': 4770,
#   'total_votes': 4770,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd5'},
#   'state': 'Georgia',
#   'county': 'Worth County',
#   'current_votes': 9285,
#   'total_votes': 9286,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd6'},
#   'state': 'Hawaii',
#   'county': 'Hawaii County',
#   'current_votes': 87814,
#   'total_votes': 87814,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd7'},
#   'state': 'Hawaii',
#   'county': 'Honolulu County',
#   'current_votes': 382114,
#   'total_votes': 382114,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd8'},
#   'state': 'Hawaii',
#   'county': 'Kauai County',
#   'current_votes': 33497,
#   'total_votes': 33497,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbd9'},
#   'state': 'Hawaii',
#   'county': 'Maui County',
#   'current_votes': 71044,
#   'total_votes': 71044,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbda'},
#   'state': 'Idaho',
#   'county': 'Ada County',
#   'current_votes': 259389,
#   'total_votes': 259389,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbdb'},
#   'state': 'Idaho',
#   'county': 'Adams County',
#   'current_votes': 2586,
#   'total_votes': 2586,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbdc'},
#   'state': 'Idaho',
#   'county': 'Bannock County',
#   'current_votes': 39553,
#   'total_votes': 39553,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbdd'},
#   'state': 'Idaho',
#   'county': 'Bear Lake County',
#   'current_votes': 3315,
#   'total_votes': 3315,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbde'},
#   'state': 'Idaho',
#   'county': 'Benewah County',
#   'current_votes': 4973,
#   'total_votes': 4973,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbdf'},
#   'state': 'Idaho',
#   'county': 'Bingham County',
#   'current_votes': 20094,
#   'total_votes': 20094,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe0'},
#   'state': 'Idaho',
#   'county': 'Blaine County',
#   'current_votes': 13289,
#   'total_votes': 13306,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe1'},
#   'state': 'Idaho',
#   'county': 'Boise County',
#   'current_votes': 4820,
#   'total_votes': 4820,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe2'},
#   'state': 'Idaho',
#   'county': 'Bonner County',
#   'current_votes': 27352,
#   'total_votes': 27352,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe3'},
#   'state': 'Idaho',
#   'county': 'Bonneville County',
#   'current_votes': 53995,
#   'total_votes': 53995,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe4'},
#   'state': 'Idaho',
#   'county': 'Boundary County',
#   'current_votes': 6313,
#   'total_votes': 6313,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe5'},
#   'state': 'Idaho',
#   'county': 'Butte County',
#   'current_votes': 1415,
#   'total_votes': 1415,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe6'},
#   'state': 'Idaho',
#   'county': 'Camas County',
#   'current_votes': 754,
#   'total_votes': 754,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe7'},
#   'state': 'Idaho',
#   'county': 'Canyon County',
#   'current_votes': 90438,
#   'total_votes': 90438,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe8'},
#   'state': 'Idaho',
#   'county': 'Caribou County',
#   'current_votes': 3416,
#   'total_votes': 3416,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbe9'},
#   'state': 'Idaho',
#   'county': 'Cassia County',
#   'current_votes': 9629,
#   'total_votes': 9629,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbea'},
#   'state': 'Idaho',
#   'county': 'Clark County',
#   'current_votes': 311,
#   'total_votes': 311,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbeb'},
#   'state': 'Idaho',
#   'county': 'Clearwater County',
#   'current_votes': 4419,
#   'total_votes': 4419,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbec'},
#   'state': 'Idaho',
#   'county': 'Custer County',
#   'current_votes': 2739,
#   'total_votes': 2739,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbed'},
#   'state': 'Idaho',
#   'county': 'Elmore County',
#   'current_votes': 10205,
#   'total_votes': 10205,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbee'},
#   'state': 'Idaho',
#   'county': 'Franklin County',
#   'current_votes': 6664,
#   'total_votes': 6664,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbef'},
#   'state': 'Idaho',
#   'county': 'Fremont County',
#   'current_votes': 6719,
#   'total_votes': 6719,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf0'},
#   'state': 'Idaho',
#   'county': 'Gem County',
#   'current_votes': 9958,
#   'total_votes': 9958,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf1'},
#   'state': 'Idaho',
#   'county': 'Gooding County',
#   'current_votes': 6050,
#   'total_votes': 6050,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf2'},
#   'state': 'Idaho',
#   'county': 'Idaho County',
#   'current_votes': 9602,
#   'total_votes': 9602,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf3'},
#   'state': 'Idaho',
#   'county': 'Jefferson County',
#   'current_votes': 14173,
#   'total_votes': 14173,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf4'},
#   'state': 'Idaho',
#   'county': 'Jerome County',
#   'current_votes': 7812,
#   'total_votes': 7812,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf5'},
#   'state': 'Idaho',
#   'county': 'Kootenai County',
#   'current_votes': 89878,
#   'total_votes': 89878,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf6'},
#   'state': 'Idaho',
#   'county': 'Latah County',
#   'current_votes': 20570,
#   'total_votes': 20593,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf7'},
#   'state': 'Idaho',
#   'county': 'Lemhi County',
#   'current_votes': 4738,
#   'total_votes': 4738,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf8'},
#   'state': 'Idaho',
#   'county': 'Lewis County',
#   'current_votes': 1870,
#   'total_votes': 1870,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbf9'},
#   'state': 'Idaho',
#   'county': 'Lincoln County',
#   'current_votes': 1940,
#   'total_votes': 1940,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbfa'},
#   'state': 'Idaho',
#   'county': 'Madison County',
#   'current_votes': 17112,
#   'total_votes': 17112,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbfb'},
#   'state': 'Idaho',
#   'county': 'Minidoka County',
#   'current_votes': 7993,
#   'total_votes': 7993,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbfc'},
#   'state': 'Idaho',
#   'county': 'Nez Perce County',
#   'current_votes': 20967,
#   'total_votes': 20967,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbfd'},
#   'state': 'Idaho',
#   'county': 'Oneida County',
#   'current_votes': 2451,
#   'total_votes': 2451,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbfe'},
#   'state': 'Idaho',
#   'county': 'Owyhee County',
#   'current_votes': 4742,
#   'total_votes': 4742,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbbff'},
#   'state': 'Idaho',
#   'county': 'Payette County',
#   'current_votes': 11293,
#   'total_votes': 11293,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc00'},
#   'state': 'Idaho',
#   'county': 'Power County',
#   'current_votes': 3086,
#   'total_votes': 3086,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc01'},
#   'state': 'Idaho',
#   'county': 'Shoshone County',
#   'current_votes': 6049,
#   'total_votes': 6049,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc02'},
#   'state': 'Idaho',
#   'county': 'Teton County',
#   'current_votes': 6347,
#   'total_votes': 6347,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc03'},
#   'state': 'Idaho',
#   'county': 'Twin Falls County',
#   'current_votes': 36680,
#   'total_votes': 36680,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc04'},
#   'state': 'Idaho',
#   'county': 'Valley County',
#   'current_votes': 7063,
#   'total_votes': 7063,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc05'},
#   'state': 'Idaho',
#   'county': 'Washington County',
#   'current_votes': 5344,
#   'total_votes': 5351,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc06'},
#   'state': 'Illinois',
#   'county': 'Adams County',
#   'current_votes': 33527,
#   'total_votes': 32202,
#   'percent': 95},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc07'},
#   'state': 'Illinois',
#   'county': 'Alexander County',
#   'current_votes': 2618,
#   'total_votes': 3010,
#   'percent': 87},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbc08'},
#   'state': 'Illinois',
# ...
#   'total_votes': 4024,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe6c'},
#   'state': 'Maine',
#   'county': 'Cary Plt.',
#   'current_votes': 0,
#   'total_votes': 0,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe6d'},
#   'state': 'Maine',
#   'county': 'Castle Hill',
#   'current_votes': 230,
#   'total_votes': 233,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe6e'},
#   'state': 'Maine',
#   'county': 'Caswell',
#   'current_votes': 134,
#   'total_votes': 136,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe6f'},
#   'state': 'Maine',
#   'county': 'Chapman',
#   'current_votes': 279,
#   'total_votes': 279,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe70'},
#   'state': 'Maine',
#   'county': 'Crystal',
#   'current_votes': 164,
#   'total_votes': 164,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe71'},
#   'state': 'Maine',
#   'county': 'Cyr Plt.',
#   'current_votes': 56,
#   'total_votes': 57,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe72'},
#   'state': 'Maine',
#   'county': 'Dyer Brook',
#   'current_votes': 150,
#   'total_votes': 150,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe73'},
#   'state': 'Maine',
#   'county': 'Eagle Lake',
#   'current_votes': 460,
#   'total_votes': 462,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe74'},
#   'state': 'Maine',
#   'county': 'Easton',
#   'current_votes': 715,
#   'total_votes': 715,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe75'},
#   'state': 'Maine',
#   'county': 'Fort Fairfield',
#   'current_votes': 1701,
#   'total_votes': 1701,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe76'},
#   'state': 'Maine',
#   'county': 'Fort Kent',
#   'current_votes': 2266,
#   'total_votes': 2266,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe77'},
#   'state': 'Maine',
#   'county': 'Frenchville',
#   'current_votes': 603,
#   'total_votes': 605,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe78'},
#   'state': 'Maine',
#   'county': 'Garfield Plt.',
#   'current_votes': 56,
#   'total_votes': 56,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe79'},
#   'state': 'Maine',
#   'county': 'Glenwood Plt.',
#   'current_votes': 1,
#   'total_votes': 1,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe7a'},
#   'state': 'Maine',
#   'county': 'Grand Isle',
#   'current_votes': 232,
#   'total_votes': 232,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe7b'},
#   'state': 'Maine',
#   'county': 'Hamlin',
#   'current_votes': 109,
#   'total_votes': 109,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe7c'},
#   'state': 'Maine',
#   'county': 'Hammond',
#   'current_votes': 46,
#   'total_votes': 47,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe7d'},
#   'state': 'Maine',
#   'county': 'Haynesville',
#   'current_votes': 63,
#   'total_votes': 63,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe7e'},
#   'state': 'Maine',
#   'county': 'Hersey',
#   'current_votes': 42,
#   'total_votes': 42,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe7f'},
#   'state': 'Maine',
#   'county': 'Hodgdon',
#   'current_votes': 812,
#   'total_votes': 812,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe80'},
#   'state': 'Maine',
#   'county': 'Houlton',
#   'current_votes': 2740,
#   'total_votes': 2740,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe81'},
#   'state': 'Maine',
#   'county': 'Island Falls',
#   'current_votes': 450,
#   'total_votes': 450,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe82'},
#   'state': 'Maine',
#   'county': 'Limestone',
#   'current_votes': 765,
#   'total_votes': 765,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe83'},
#   'state': 'Maine',
#   'county': 'Linneus',
#   'current_votes': 508,
#   'total_votes': 508,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe84'},
#   'state': 'Maine',
#   'county': 'Littleton',
#   'current_votes': 531,
#   'total_votes': 531,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe85'},
#   'state': 'Maine',
#   'county': 'Ludlow',
#   'current_votes': 255,
#   'total_votes': 255,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe86'},
#   'state': 'Maine',
#   'county': 'Macwahoc Plt.',
#   'current_votes': 43,
#   'total_votes': 43,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe87'},
#   'state': 'Maine',
#   'county': 'Madawaska',
#   'current_votes': 2112,
#   'total_votes': 2112,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe88'},
#   'state': 'Maine',
#   'county': 'Mapleton',
#   'current_votes': 1159,
#   'total_votes': 1159,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe89'},
#   'state': 'Maine',
#   'county': 'Mars Hill',
#   'current_votes': 742,
#   'total_votes': 742,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe8a'},
#   'state': 'Maine',
#   'county': 'Masardis',
#   'current_votes': 122,
#   'total_votes': 124,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe8b'},
#   'state': 'Maine',
#   'county': 'Merrill',
#   'current_votes': 136,
#   'total_votes': 136,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe8c'},
#   'state': 'Maine',
#   'county': 'Monticello',
#   'current_votes': 434,
#   'total_votes': 434,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe8d'},
#   'state': 'Maine',
#   'county': 'Moro Plt.',
#   'current_votes': 29,
#   'total_votes': 29,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe8e'},
#   'state': 'Maine',
#   'county': 'Nashville Plt.',
#   'current_votes': 23,
#   'total_votes': 23,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe8f'},
#   'state': 'Maine',
#   'county': 'New Canada',
#   'current_votes': 159,
#   'total_votes': 159,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe90'},
#   'state': 'Maine',
#   'county': 'New Limerick',
#   'current_votes': 372,
#   'total_votes': 372,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe91'},
#   'state': 'Maine',
#   'county': 'New Sweden',
#   'current_votes': 322,
#   'total_votes': 352,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe92'},
#   'state': 'Maine',
#   'county': 'Oakfield',
#   'current_votes': 408,
#   'total_votes': 408,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe93'},
#   'state': 'Maine',
#   'county': 'Orient',
#   'current_votes': 90,
#   'total_votes': 90,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe94'},
#   'state': 'Maine',
#   'county': 'Penobscot Nation Vot Dst',
#   'current_votes': 302,
#   'total_votes': 304,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe95'},
#   'state': 'Maine',
#   'county': 'Perham',
#   'current_votes': 214,
#   'total_votes': 214,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe96'},
#   'state': 'Maine',
#   'county': 'Portage Lake',
#   'current_votes': 265,
#   'total_votes': 268,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe97'},
#   'state': 'Maine',
#   'county': 'Presque Isle',
#   'current_votes': 4239,
#   'total_votes': 4239,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe98'},
#   'state': 'Maine',
#   'county': 'Reed Plt.',
#   'current_votes': 81,
#   'total_votes': 81,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe99'},
#   'state': 'Maine',
#   'county': 'Saint Agatha',
#   'current_votes': 637,
#   'total_votes': 638,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe9a'},
#   'state': 'Maine',
#   'county': 'St. Francis',
#   'current_votes': 245,
#   'total_votes': 245,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe9b'},
#   'state': 'Maine',
#   'county': 'St. John Plt.',
#   'current_votes': 171,
#   'total_votes': 171,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe9c'},
#   'state': 'Maine',
#   'county': 'Sherman',
#   'current_votes': 665,
#   'total_votes': 676,
#   'percent': 95},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe9d'},
#   'state': 'Maine',
#   'county': 'Smyrna',
#   'current_votes': 157,
#   'total_votes': 157,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe9e'},
#   'state': 'Maine',
#   'county': 'Stockholm',
#   'current_votes': 160,
#   'total_votes': 162,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbe9f'},
#   'state': 'Maine',
#   'county': 'Van Buren',
#   'current_votes': 898,
#   'total_votes': 898,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea0'},
#   'state': 'Maine',
#   'county': 'Wade',
#   'current_votes': 142,
#   'total_votes': 145,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea1'},
#   'state': 'Maine',
#   'county': 'Wallagrass',
#   'current_votes': 291,
#   'total_votes': 292,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea2'},
#   'state': 'Maine',
#   'county': 'Washburn',
#   'current_votes': 820,
#   'total_votes': 820,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea3'},
#   'state': 'Maine',
#   'county': 'Westfield',
#   'current_votes': 267,
#   'total_votes': 268,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea4'},
#   'state': 'Maine',
#   'county': 'Westmanland',
#   'current_votes': 55,
#   'total_votes': 55,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea5'},
#   'state': 'Maine',
#   'county': 'Weston',
#   'current_votes': 182,
#   'total_votes': 182,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea6'},
#   'state': 'Maine',
#   'county': 'Winterville Plt.',
#   'current_votes': 125,
#   'total_votes': 125,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea7'},
#   'state': 'Maine',
#   'county': 'Woodland',
#   'current_votes': 662,
#   'total_votes': 664,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea8'},
#   'state': 'Maine',
#   'county': 'Baldwin',
#   'current_votes': 999,
#   'total_votes': 971,
#   'percent': 95},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbea9'},
#   'state': 'Maine',
#   'county': 'Bridgton',
#   'current_votes': 3268,
#   'total_votes': 3268,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeaa'},
#   'state': 'Maine',
#   'county': 'Brunswick',
#   'current_votes': 13892,
#   'total_votes': 13905,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeab'},
#   'state': 'Maine',
#   'county': 'Cape Elizabeth',
#   'current_votes': 6939,
#   'total_votes': 6970,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeac'},
#   'state': 'Maine',
#   'county': 'Casco',
#   'current_votes': 2296,
#   'total_votes': 2296,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbead'},
#   'state': 'Maine',
#   'county': 'Chebeague Island',
#   'current_votes': 330,
#   'total_votes': 330,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeae'},
#   'state': 'Maine',
#   'county': 'Cumberland',
#   'current_votes': 6002,
#   'total_votes': 6045,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeaf'},
#   'state': 'Maine',
#   'county': 'Falmouth',
#   'current_votes': 9031,
#   'total_votes': 9057,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb0'},
#   'state': 'Maine',
#   'county': 'Freeport',
#   'current_votes': 6184,
#   'total_votes': 6192,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb1'},
#   'state': 'Maine',
#   'county': 'Frye Island',
#   'current_votes': 57,
#   'total_votes': 57,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb2'},
#   'state': 'Maine',
#   'county': 'Gorham',
#   'current_votes': 11115,
#   'total_votes': 11146,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb3'},
#   'state': 'Maine',
#   'county': 'Gray',
#   'current_votes': 5390,
#   'total_votes': 5390,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb4'},
#   'state': 'Maine',
#   'county': 'Harpswell',
#   'current_votes': 3884,
#   'total_votes': 3899,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb5'},
#   'state': 'Maine',
#   'county': 'Harrison',
#   'current_votes': 1574,
#   'total_votes': 1552,
#   'percent': 95},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb6'},
#   'state': 'Maine',
#   'county': 'Long Island',
#   'current_votes': 191,
#   'total_votes': 191,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb7'},
#   'state': 'Maine',
#   'county': 'Naples',
#   'current_votes': 2495,
#   'total_votes': 2495,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb8'},
#   'state': 'Maine',
#   'county': 'New Gloucester',
#   'current_votes': 3599,
#   'total_votes': 3607,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeb9'},
#   'state': 'Maine',
#   'county': 'North Yarmouth',
#   'current_votes': 2960,
#   'total_votes': 2981,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeba'},
#   'state': 'Maine',
#   'county': 'Portland',
#   'current_votes': 41544,
#   'total_votes': 41569,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbebb'},
#   'state': 'Maine',
#   'county': 'Pownal',
#   'current_votes': 1206,
#   'total_votes': 1210,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbebc'},
#   'state': 'Maine',
#   'county': 'Raymond',
#   'current_votes': 3142,
#   'total_votes': 3142,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbebd'},
#   'state': 'Maine',
#   'county': 'Scarborough',
#   'current_votes': 15057,
#   'total_votes': 15071,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbebe'},
#   'state': 'Maine',
#   'county': 'Sebago',
#   'current_votes': 1277,
#   'total_votes': 1277,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbebf'},
#   'state': 'Maine',
#   'county': 'South Portland',
#   'current_votes': 16286,
#   'total_votes': 16286,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec0'},
#   'state': 'Maine',
#   'county': 'Standish',
#   'current_votes': 6060,
#   'total_votes': 6075,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec1'},
#   'state': 'Maine',
#   'county': 'Westbrook',
#   'current_votes': 11187,
#   'total_votes': 11187,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec2'},
#   'state': 'Maine',
#   'county': 'Windham',
#   'current_votes': 11442,
#   'total_votes': 11446,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec3'},
#   'state': 'Maine',
#   'county': 'Yarmouth',
#   'current_votes': 6358,
#   'total_votes': 6449,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec4'},
#   'state': 'Maine',
#   'county': 'Avon',
#   'current_votes': 263,
#   'total_votes': 263,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec5'},
#   'state': 'Maine',
#   'county': 'Carrabassett Valley',
#   'current_votes': 527,
#   'total_votes': 534,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec6'},
#   'state': 'Maine',
#   'county': 'Carthage',
#   'current_votes': 312,
#   'total_votes': 312,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec7'},
#   'state': 'Maine',
#   'county': 'Chesterville',
#   'current_votes': 799,
#   'total_votes': 807,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec8'},
#   'state': 'Maine',
#   'county': 'Coplin Plt.',
#   'current_votes': 110,
#   'total_votes': 111,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbec9'},
#   'state': 'Maine',
#   'county': 'Dallas Plt.',
#   'current_votes': 209,
#   'total_votes': 212,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbeca'},
#   'state': 'Maine',
#   'county': 'Eustis',
#   'current_votes': 447,
#   'total_votes': 449,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbecb'},
#   'state': 'Maine',
#   'county': 'Farmington',
#   'current_votes': 3906,
#   'total_votes': 3907,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbecc'},
#   'state': 'Maine',
#   'county': 'Industry',
#   'current_votes': 504,
#   'total_votes': 507,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbecd'},
#   'state': 'Maine',
#   'county': 'Jay',
#   'current_votes': 2665,
#   'total_votes': 2665,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbece'},
#   'state': 'Maine',
#   'county': 'Kingfield',
#   'current_votes': 888,
#   'total_votes': 888,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbecf'},
#   'state': 'Maine',
#   'county': 'New Sharon',
#   'current_votes': 956,
#   'total_votes': 956,
#   'percent': 100},
#  {'_id': {'$oid': '60f105bfe3c510961b8bbed0'},
#   'state': 'Maine',
#   'county': 'New Vineyard',
#   'current_votes': 463,
#   'total_votes': 463,
#   'percent': 100},
#  ...]

# %%
    candidate = mongo.db.pCandidate.find()
    state = mongo.db.pState.find()
    county = mongo.db.pCounty.find()

    all_data = [candidate, state, county]

    return_list = []

    for dataset in all_data:

        list_cur = list(dataset)
        json_data = dumps(list_cur)
        return_list.append(json_data)
    
    # Pull only candidate data
    candidate_data = return_list[0]
    
    # Convert string of json to a json file
    candidate_json = json.loads(candidate_data)
    
    # Convert json file to data frame
    df = pd.DataFrame.from_records(candidate_json)
    
    # Filter data by our two candidates (Biden and Trump)
    candidate_df = df.loc[(df["candidate"] == "Joe Biden") | (df["candidate"] == "Donald Trump"),:]
    
    # Group data by states
    condensed_df = candidate_df.groupby(["state","candidate"]).sum()
    
    condensed_df
# Out:
#                             total_votes   won
# state         candidate
# Alabama       Donald Trump      1441168  54.0
#               Joe Biden          849648  13.0
# Alaska        Donald Trump       189892  20.0
#               Joe Biden          153405  17.0
# Arizona       Donald Trump      1661686  10.0
# ...                                 ...   ...
# West Virginia Joe Biden          235984   0.0
# Wisconsin     Donald Trump      1610065  58.0
#               Joe Biden         1630673  14.0
# Wyoming       Donald Trump       193559  21.0
#               Joe Biden           73491   2.0
#
# [102 rows x 2 columns]

# %%
    for index, row in condensed_df.iterrows():
        print(row.name[0])
# Out:
# Alabama
# Alabama
# Alaska
# Alaska
# Arizona
# Arizona
# Arkansas
# Arkansas
# California
# California
# Colorado
# Colorado
# Connecticut
# Connecticut
# Delaware
# Delaware
# District of Columbia
# District of Columbia
# Florida
# Florida
# Georgia
# Georgia
# Hawaii
# Hawaii
# Idaho
# Idaho
# Illinois
# Illinois
# Indiana
# Indiana
# Iowa
# Iowa
# Kansas
# Kansas
# Kentucky
# Kentucky
# Louisiana
# Louisiana
# Maine
# Maine
# Maryland
# Maryland
# Massachusetts
# Massachusetts
# Michigan
# Michigan
# Minnesota
# Minnesota
# Mississippi
# Mississippi
# Missouri
# Missouri
# Montana
# Montana
# Nebraska
# Nebraska
# Nevada
# Nevada
# New Hampshire
# New Hampshire
# New Jersey
# New Jersey
# New Mexico
# New Mexico
# New York
# New York
# North Carolina
# North Carolina
# North Dakota
# North Dakota
# Ohio
# Ohio
# Oklahoma
# Oklahoma
# Oregon
# Oregon
# Pennsylvania
# Pennsylvania
# Rhode Island
# Rhode Island
# South Carolina
# South Carolina
# South Dakota
# South Dakota
# Tennessee
# Tennessee
# Texas
# Texas
# Utah
# Utah
# Vermont
# Vermont
# Virginia
# Virginia
# Washington
# Washington
# West Virginia
# West Virginia
# Wisconsin
# Wisconsin
# Wyoming
# Wyoming
